# %% [markdown]
# # Exercici 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

vols_df=pd.read_csv("H:\_vertex\_formacio\_python - cibernarium\_03\_03_15\DelayedFlights.csv",usecols=["index","Year","Month","DayofMonth","DayOfWeek","DepTime","CRSDepTime","ArrTime","CRSArrTime","UniqueCarrier","FlightNum","ActualElapsedTime","CRSElapsedTime","AirTime","ArrDelay","DepDelay","Origin","Dest","Distance","Diverted","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay","LateAircraftDelay"])

# %%
print('Dataset de {} dades en {} variables/columnes.'.format(vols_df.shape[0],vols_df.shape[1]))
# Out:
# Dataset de 1936758 dades en 25 variables/columnes.

# %%
vols_df[:10]
# Out:
#    index  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0      0  2008      1           3          4   2003.0        1955   2211.0
# 1      1  2008      1           3          4    754.0         735   1002.0
# 2      2  2008      1           3          4    628.0         620    804.0
# 3      4  2008      1           3          4   1829.0        1755   1959.0
# 4      5  2008      1           3          4   1940.0        1915   2121.0
# 5      6  2008      1           3          4   1937.0        1830   2037.0
# 6     10  2008      1           3          4    706.0         700    916.0
# 7     11  2008      1           3          4   1644.0        1510   1845.0
# 8     15  2008      1           3          4   1029.0        1020   1021.0
# 9     16  2008      1           3          4   1452.0        1425   1640.0
#
#    CRSArrTime UniqueCarrier  ...  DepDelay  Origin  Dest  Distance  Diverted  \
# ...

# %% [markdown]
# Forçar que la columna índex sigui precisament l'index de la taula doncs defineix unívocament a cadascuna de les diferents filesde la taula

# %%
vols_df.set_index('index')
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# index
# 0        2008      1           3          4   2003.0        1955   2211.0
# 1        2008      1           3          4    754.0         735   1002.0
# 2        2008      1           3          4    628.0         620    804.0
# 4        2008      1           3          4   1829.0        1755   1959.0
# 5        2008      1           3          4   1940.0        1915   2121.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7009710  2008     12          13          6   1250.0        1220   1617.0
# 7009717  2008     12          13          6    657.0         600    904.0
# 7009718  2008     12          13          6   1007.0         847   1149.0
# 7009726  2008     12          13          6   1251.0        1240   1446.0
# 7009727  2008     12          13          6   1110.0        1103   1413.0
#
# ...

# %%
vols_df[:10]
# Out:
#    index  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0      0  2008      1           3          4   2003.0        1955   2211.0
# 1      1  2008      1           3          4    754.0         735   1002.0
# 2      2  2008      1           3          4    628.0         620    804.0
# 3      4  2008      1           3          4   1829.0        1755   1959.0
# 4      5  2008      1           3          4   1940.0        1915   2121.0
# 5      6  2008      1           3          4   1937.0        1830   2037.0
# 6     10  2008      1           3          4    706.0         700    916.0
# 7     11  2008      1           3          4   1644.0        1510   1845.0
# 8     15  2008      1           3          4   1029.0        1020   1021.0
# 9     16  2008      1           3          4   1452.0        1425   1640.0
#
#    CRSArrTime UniqueCarrier  ...  DepDelay  Origin  Dest  Distance  Diverted  \
# ...

# %% [markdown]
# # Exercici 2

# %% [markdown]
# ### Informe complet del data set

# %% [markdown]
# -- Resumeix estadísticament les columnes d’interès

# %%
print('Resum estadístic de les columnes d’interès')
vols_df.describe()
# Out:
# Resum estadístic de les columnes d’interès
#               index       Year         Month    DayofMonth     DayOfWeek  \
# count  1.936758e+06  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06
# mean   3.341651e+06     2008.0  6.111106e+00  1.575347e+01  3.984827e+00
# std    2.066065e+06        0.0  3.482546e+00  8.776272e+00  1.995966e+00
# min    0.000000e+00     2008.0  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.517452e+06     2008.0  3.000000e+00  8.000000e+00  2.000000e+00
# 50%    3.242558e+06     2008.0  6.000000e+00  1.600000e+01  4.000000e+00
# 75%    4.972467e+06     2008.0  9.000000e+00  2.300000e+01  6.000000e+00
# max    7.009727e+06     2008.0  1.200000e+01  3.100000e+01  7.000000e+00
#
#             DepTime    CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.936758e+06  1.936758e+06  1.929648e+06  1.936758e+06  1.936758e+06
# mean   1.518534e+03  1.467473e+03  1.610141e+03  1.634225e+03  2.184263e+03
# ...

# %% [markdown]
# -- Troba quantes dades faltants hi ha per columna

# %%
print('Llista de dades faltants per columna')
vols_df.isnull().sum(axis=0)
# Out:
# Llista de dades faltants per columna
# index                     0
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# ArrDelay               8387
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# dtype: int64

# %%
print('Llista de dades totals per columna')
vols_df.info(null_counts=True)
# Out:
# Llista de dades totals per columna
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1936758 entries, 0 to 1936757
# Data columns (total 25 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   index              1936758 non-null  int64
#  1   Year               1936758 non-null  int64
#  2   Month              1936758 non-null  int64
#  3   DayofMonth         1936758 non-null  int64
#  4   DayOfWeek          1936758 non-null  int64
#  5   DepTime            1936758 non-null  float64
#  6   CRSDepTime         1936758 non-null  int64
#  7   ArrTime            1929648 non-null  float64
#  8   CRSArrTime         1936758 non-null  int64
#  9   UniqueCarrier      1936758 non-null  object
#  10  FlightNum          1936758 non-null  int64
#  11  ActualElapsedTime  1928371 non-null  float64
#  12  CRSElapsedTime     1936560 non-null  float64
#  13  AirTime            1928371 non-null  float64
# ...

# %%
vols_df.isnull().sum(axis=0)
# Out:
# index                     0
# Year                      0
# Month                     0
# DayofMonth                0
# DayOfWeek                 0
# DepTime                   0
# CRSDepTime                0
# ArrTime                7110
# CRSArrTime                0
# UniqueCarrier             0
# FlightNum                 0
# ActualElapsedTime      8387
# CRSElapsedTime          198
# AirTime                8387
# ArrDelay               8387
# DepDelay                  0
# Origin                    0
# Dest                      0
# Distance                  0
# Diverted                  0
# CarrierDelay         689270
# WeatherDelay         689270
# NASDelay             689270
# SecurityDelay        689270
# LateAircraftDelay    689270
# dtype: int64

# %%
print('Per tal de coneixer la quantitat de valors nuls de una columna també es pot usar la funció isnull() acompanyade a de sum()')
vols_df.CarrierDelay.isnull().sum()
# Out:
# Per tal de coneixer la quantitat de valors nuls de una columna també es pot usar la funció isnull() acompanyade a de sum()
# 689270

# %% [markdown]
# -- Crea columnes noves:

# %% [markdown]
#     a. velocitat mitjana del vol,

# %%
print('Càlcul de la velocitat mitja en vol en km/h. Cal tenir en compte que la distancia està inicialment en km i el temps en minuts.')
vols_df.loc[:,'AverageSpeedOnAir']=round(vols_df['Distance']/(vols_df['AirTime']/60),0)
vols_df[['index','Distance','AirTime','AverageSpeedOnAir']]
# Out:
# Càlcul de la velocitat mitja en vol en km/h. Cal tenir en compte que la distancia està inicialment en km i el temps en minuts.
#            index  Distance  AirTime  AverageSpeedOnAir
# 0              0       810    116.0              419.0
# 1              1       810    113.0              430.0
# 2              2       515     76.0              407.0
# 3              4       515     77.0              401.0
# 4              5       688     87.0              474.0
# ...          ...       ...      ...                ...
# 1936753  7009710       906    120.0              453.0
# 1936754  7009717       481     78.0              370.0
# 1936755  7009718       689    122.0              339.0
# 1936756  7009726       533     89.0              359.0
# 1936757  7009727       874    104.0              504.0
#
# [1936758 rows x 4 columns]

# %% [markdown]
#      b. si ha arribat tard o no...

# %%
vols_df.loc[:,'ArrDelayTrueOrFalse']=vols_df['ArrDelay']
vols_df['ArrDelayTrueOrFalse']=vols_df['ArrDelayTrueOrFalse'].apply(lambda x: 'Retard' if x>0 or x<0 else 'Puntual')
vols_df[['index','ArrDelay','ArrDelayTrueOrFalse']]
# Out:
#            index  ArrDelay ArrDelayTrueOrFalse
# 0              0     -14.0              Retard
# 1              1       2.0              Retard
# 2              2      14.0              Retard
# 3              4      34.0              Retard
# 4              5      11.0              Retard
# ...          ...       ...                 ...
# 1936753  7009710      25.0              Retard
# 1936754  7009717      75.0              Retard
# 1936755  7009718      99.0              Retard
# 1936756  7009726       9.0              Retard
# 1936757  7009727      -5.0              Retard
#
# [1936758 rows x 3 columns]

# %% [markdown]
#     c. taula de les aerolínies amb més endarreriments acumulats

# %%
print('Les 3 companyies que acumulen de mitja els majors retards son (en minuts):')
vols_df['UniqueCarrier'].describe()
vols_df.loc[:,'AcumulatedDelay']=vols_df['ArrDelay']+vols_df['DepDelay']+vols_df['CarrierDelay']+vols_df['WeatherDelay']+vols_df['NASDelay']+vols_df['SecurityDelay']+vols_df['LateAircraftDelay']
vols_df_agrupat_x_companyia_aerea_retards_acumulats=vols_df.groupby(['UniqueCarrier']).agg({'AcumulatedDelay': np.median})
vols_df_agrupat_x_companyia_aerea_retards_acumulats.sort_values(by='AcumulatedDelay', ascending=False)[0:3]
# Out:
# Les 3 companyies que acumulen de mitja els majors retards son (en minuts):
#                AcumulatedDelay
# UniqueCarrier
# B6                       159.0
# UA                       147.0
# YV                       146.0

# %%
vols_df_agrupat_x_companyia_aerea_retards_acumulats.sort_values(by='AcumulatedDelay', ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='UniqueCarrier'>

# %% [markdown]
#     c. quins són els vols més llargs?

# %%
print('Els 3 vols que recorren, de mitja, les distancies més llargues son (en km):')
vols_df['FlightNum'].describe()
vols_df_agrupat_x_numero_de_vol_distancia=vols_df.groupby(['FlightNum']).agg({'Distance': np.median})
vols_df_agrupat_x_numero_de_vol_distancia.sort_values(by='Distance', ascending=False)[0:3]
# Out:
# Els 3 vols que recorren, de mitja, les distancies més llargues son (en km):
#            Distance
# FlightNum
# 181          2446.0
# 186          2433.0
# 73           2398.0

# %% [markdown]
#     c. quins són els vols més endarrerits?

# %%
print('Els 3 vols que, de mitja, més sendarrereixen son (en minuts):')
vols_df['FlightNum'].describe()
vols_df_agrupat_x_numero_de_vol_endarrerits=vols_df.groupby(['FlightNum']).agg({'DepDelay': np.median})
vols_df_agrupat_x_numero_de_vol_endarrerits.sort_values(by='DepDelay', ascending=False)[0:3]
# Out:
# Els 3 vols que, de mitja, més sendarrereixen son (en minuts):
#            DepDelay
# FlightNum
# 6899          375.5
# 7487          350.0
# 7405          247.0

# %% [markdown]
# # Exercici 3

# %%
vols_df.to_csv("H:\_vertex\_formacio\_python - cibernarium\_03\_03_15\DelayedFlights_net.csv") 
print(vols_df.describe())
# Out:
#               index       Year         Month    DayofMonth     DayOfWeek  \
# count  1.936758e+06  1936758.0  1.936758e+06  1.936758e+06  1.936758e+06
# mean   3.341651e+06     2008.0  6.111106e+00  1.575347e+01  3.984827e+00
# std    2.066065e+06        0.0  3.482546e+00  8.776272e+00  1.995966e+00
# min    0.000000e+00     2008.0  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.517452e+06     2008.0  3.000000e+00  8.000000e+00  2.000000e+00
# 50%    3.242558e+06     2008.0  6.000000e+00  1.600000e+01  4.000000e+00
# 75%    4.972467e+06     2008.0  9.000000e+00  2.300000e+01  6.000000e+00
# max    7.009727e+06     2008.0  1.200000e+01  3.100000e+01  7.000000e+00
#
#             DepTime    CRSDepTime       ArrTime    CRSArrTime     FlightNum  \
# count  1.936758e+06  1.936758e+06  1.929648e+06  1.936758e+06  1.936758e+06
# mean   1.518534e+03  1.467473e+03  1.610141e+03  1.634225e+03  2.184263e+03
# std    4.504853e+02  4.247668e+02  5.481781e+02  4.646347e+02  1.944702e+03
# ...

# %% [markdown]
# # Exercici VISUALITZACIONS Tasca 6

# %% [markdown]
# -- Visualització amb la variable categòrica UniqueCarrier

# %%
from IPython import display
from base64 import b64decode
imatge_exercici_01_01="...%0A"
display.Image(b64decode(imatge_exercici_01_01))

# %% [markdown]
# -- Visualització amb la variable variable numèrica ArrDelay

# %%
imatge_exercici_01_02="..."
display.Image(b64decode(imatge_exercici_01_02))

# %% [markdown]
# -- Visualització amb una variable numèrica i una categòrica (AcumulatedDelay i UniqueCarrier)

# %%
imatge_exercici_01_03="..."
display.Image(b64decode(imatge_exercici_01_03))

# %% [markdown]
# -- Visualització amb dues variables numèriques (ArrDelay i DepDelay)

# %%
imatge_exercici_01_04="..."
display.Image(b64decode(imatge_exercici_01_04))

# %% [markdown]
# -- Visualització amb tres variables (ArrDelay, DepDelay i UniqueCarrier)

# %%
imatge_exercici_01_04="...%0A"
display.Image(b64decode(imatge_exercici_01_04))

# %% [markdown]
# -- Visualització amb més de tres variables (ArrDelay, DepDelay, AirTime i UniqueCarrier)

# %%
imatge_exercici_01_05="..."
display.Image(b64decode(imatge_exercici_01_05))
