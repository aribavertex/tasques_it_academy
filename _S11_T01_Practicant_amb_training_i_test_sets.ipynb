# %% [markdown]
# <html>
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=windows-1252">
# <meta name=Generator content="Microsoft Word 15 (filtered)">
# <style>
# <!--
#  /* Font Definitions */
#  @font-face
# 	{font-family:Wingdings;
# 	panose-1:5 0 0 0 0 0 0 0 0 0;}
# @font-face
# 	{font-family:"Cambria Math";
# 	panose-1:2 4 5 3 5 4 6 3 2 4;}
# @font-face
# 	{font-family:Calibri;
# 	panose-1:2 15 5 2 2 2 4 3 2 4;}
# @font-face
# 	{font-family:"Open Sans";
# 	panose-1:2 11 6 6 3 5 4 2 2 4;}
#  /* Style Definitions */
#  p.MsoNormal, li.MsoNormal, div.MsoNormal
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:0in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraph, li.MsoListParagraph, div.MsoListParagraph
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpFirst, li.MsoListParagraphCxSpFirst, div.MsoListParagraphCxSpFirst
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:0in;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpMiddle, li.MsoListParagraphCxSpMiddle, div.MsoListParagraphCxSpMiddle
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:0in;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpLast, li.MsoListParagraphCxSpLast, div.MsoListParagraphCxSpLast
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# .MsoChpDefault
# 	{font-family:"Calibri",sans-serif;}
# .MsoPapDefault
# 	{margin-bottom:8.0pt;
# 	line-height:107%;}
# @page WordSection1
# 	{size:595.3pt 841.9pt;
# 	margin:70.85pt 23.8pt 70.85pt 27.0pt;}
# div.WordSection1
# 	{page:WordSection1;}
#  /* List Definitions */
#  ol
# 	{margin-bottom:0in;}
# ul
# 	{margin-bottom:0in;}
# -->
# </style>
#
# </head>
#
# <body lang=EN-GB link="#0563C1" vlink="#954F72" style='word-wrap:break-word'>
#
# <div class=WordSection1>
#
# <p class=MsoNormal><b><span lang=CA style='font-size:20.0pt;line-height:107%;
# font-family:"Open Sans",sans-serif;color:#0070C0'>S11 T01: Practicant amb
# training i test sets</span></b></p>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><b><span
# lang=CA style='font-size:14.0pt;font-family:"Open Sans",sans-serif'>Descripció:</span></b></p>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><span lang=CA
# style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>Familiaritza't amb
# la programació científica mitjançant la llibreria SKLearn / Scikitlearn </span></p>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><span lang=CA
# style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>&nbsp;</span></p>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><b><i><span
# lang=CA style='font-size:14.0pt;font-family:"Open Sans",sans-serif'>Nivell 1</span></i></b></p>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><span lang=CA
# style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraph style='margin-top:0in;margin-right:0in;margin-bottom:
# 0in;margin-left:.25in;text-indent:-.25in;line-height:normal'><span lang=CA
# style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>·<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><u><span lang=CA style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>Exercici
# 1</span></u></p>
#
# <p class=MsoNormal style='margin-bottom:0in;text-align:justify;line-height:
# normal'><span lang=CA style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>Parteix
# el conjunt de dadesDelayedFlights.csv en train i test. Estudia els dos conjunts
# per separat, a nivell descriptiu.</span></p>
#
# </div>
#
# </body>
#
# </html>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
pd.set_option('display.max_columns', None)

# %%
vols = pd.read_csv('H:\_vertex\_formacio\_python - cibernarium\_04\_04_08\DelayedFlights_visualitzacio_net.csv')

vols.head()
# Out:
#    Unnamed: 0  index  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0           0      0  2008      1           3          4   2003.0        1955
# 1           1      1  2008      1           3          4    754.0         735
# 2           2      2  2008      1           3          4    628.0         620
# 3           3      4  2008      1           3          4   1829.0        1755
# 4           4      5  2008      1           3          4   1940.0        1915
#
#    ArrTime  CRSArrTime UniqueCarrier  FlightNum  ActualElapsedTime  \
# 0   2211.0        2225            WN        335              128.0
# 1   1002.0        1000            WN       3231              128.0
# 2    804.0         750            WN        448               96.0
# 3   1959.0        1925            WN       3920               90.0
# 4   2121.0        2110            WN        378              101.0
#
#    CRSElapsedTime  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# ...

# %%
# Eliminar columna anomenada Unnamed: 0
vols = vols.rename(columns={"Unnamed: 0": "id"})

# Fixar com a index la columna id
vols = vols.set_index('id')

# Elimina la columna index
vols.drop('index', axis='columns', inplace=True)

vols.head()
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# id
# 0   2008      1           3          4   2003.0        1955   2211.0
# 1   2008      1           3          4    754.0         735   1002.0
# 2   2008      1           3          4    628.0         620    804.0
# 3   2008      1           3          4   1829.0        1755   1959.0
# 4   2008      1           3          4   1940.0        1915   2121.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ActualElapsedTime  CRSElapsedTime  \
# id
# 0         2225            WN        335              128.0           150.0
# 1         1000            WN       3231              128.0           145.0
# 2          750            WN        448               96.0            90.0
# 3         1925            WN       3920               90.0            90.0
# 4         2110            WN        378              101.0           115.0
#
#     AirTime  ArrDelay  DepDelay Origin Dest  Distance  Diverted  CarrierDelay  \
# id
# ...

# %%
# Estadístics de resum de cada columna
vols.describe().round(2)
# Out:
#             Year       Month  DayofMonth   DayOfWeek     DepTime  CRSDepTime  \
# count  1773764.0  1773764.00  1773764.00  1773764.00  1773764.00  1773764.00
# mean      2008.0        6.10       15.74        3.98     1506.34     1464.16
# std          0.0        3.47        8.76        1.99      439.40      425.44
# min       2008.0        1.00        1.00        1.00        1.00        0.00
# 25%       2008.0        3.00        8.00        2.00     1156.00     1130.00
# 50%       2008.0        6.00       16.00        4.00     1534.00     1505.00
# 75%       2008.0        9.00       23.00        6.00     1849.00     1815.00
# max       2008.0       12.00       31.00        7.00     2400.00     2359.00
#
#           ArrTime  CRSArrTime   FlightNum  ActualElapsedTime  CRSElapsedTime  \
# count  1773764.00  1773764.00  1773764.00         1773764.00      1773764.00
# mean      1620.40     1629.94     2162.66             132.03          134.06
# ...

# %%
# Eliminar algunes variables que no creiem siguin d'interés
vols = vols.drop(['ActualElapsedTime', 'CRSElapsedTime', 'Diverted', 'CarrierDelay', 'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'], axis=1)

vols.head()
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# id
# 0   2008      1           3          4   2003.0        1955   2211.0
# 1   2008      1           3          4    754.0         735   1002.0
# 2   2008      1           3          4    628.0         620    804.0
# 3   2008      1           3          4   1829.0        1755   1959.0
# 4   2008      1           3          4   1940.0        1915   2121.0
#
#     CRSArrTime UniqueCarrier  FlightNum  AirTime  ArrDelay  DepDelay Origin  \
# id
# 0         2225            WN        335    116.0     -14.0       8.0    IAD
# 1         1000            WN       3231    113.0       2.0      19.0    IAD
# 2          750            WN        448     76.0      14.0       8.0    IND
# 3         1925            WN       3920     77.0      34.0      34.0    IND
# 4         2110            WN        378     87.0      11.0      25.0    IND
#
#    Dest  Distance  AcumulatedDelay
# id
# 0   TPA       810              NaN
# ...

# %%
# Creació de la mostra d'entrenament i validació
mostra_entrenament, mostra_validacio = train_test_split(vols, test_size=0.2, random_state=2)

print("Tamany de mostra d'entrenament: {}".format(mostra_entrenament.shape[0]))
print("Tamany de mostra de validació: {}".format(mostra_validacio.shape[0]))

display(mostra_entrenament.head())
display(mostra_validacio.head())
# Out:
# Tamany de mostra d'entrenament: 1419011
# Tamany de mostra de validació: 354753
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# id
# 536445   2008      3          30          7   1800.0        1735   2039.0
# 1578251  2008     10          23          4   2036.0        2020   2036.0
# 424434   2008      3          13          4   1737.0        1720   2121.0
# 1443565  2008      9          26          5   1746.0        1700   1803.0
# 432924   2008      3          19          3   2105.0        1959   2210.0
#
#          CRSArrTime UniqueCarrier  FlightNum  AirTime  ArrDelay  DepDelay  \
# id
# 536445         2000            AA       1136    137.0      39.0      25.0
# 1578251        2015            DL       1597     32.0      21.0      16.0
# 424434         2119            XE       2058    143.0       2.0      17.0
# 1443565        1735            WN        268     63.0      28.0      46.0
# ...

# %%
# Comparativa de diferents estadístics de columnes numériques per a les mostres d'entrenament i de validació
# display(mostra_entrenament[['AirTime','ArrDelay','DepDelay','Distance']].describe().round(2))
display(mostra_entrenament.describe(include=[np.number]).round(2))
display(mostra_validacio.describe(include=[np.number]).round(2))
# Out:
#             Year       Month  DayofMonth   DayOfWeek     DepTime  CRSDepTime  \
# count  1419011.0  1419011.00  1419011.00  1419011.00  1419011.00  1419011.00
# mean      2008.0        6.10       15.74        3.98     1506.59     1464.47
# std          0.0        3.47        8.76        1.99      439.49      425.48
# min       2008.0        1.00        1.00        1.00        1.00        0.00
# 25%       2008.0        3.00        8.00        2.00     1156.00     1130.00
# 50%       2008.0        6.00       16.00        4.00     1534.00     1505.00
# 75%       2008.0        9.00       23.00        6.00     1849.00     1815.00
# max       2008.0       12.00       31.00        7.00     2400.00     2359.00
#
#           ArrTime  CRSArrTime   FlightNum     AirTime    ArrDelay    DepDelay  \
# count  1419011.00  1419011.00  1419011.00  1419011.00  1419011.00  1419011.00
# mean      1620.19     1629.89     2162.55      108.05       29.58       31.61
# ...

# %% [markdown]
# #### La descripció retorna valors en els estadístics molt similars,sobretot a nivell de mitjes, desviacions típiques i distribució interquartílica

# %%
# Comparativa de diferents estadístics de columnes categoriques per a les mostres d'entrenament i de validació
display(mostra_entrenament[['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'UniqueCarrier', 'FlightNum', 'Origin', 'Dest']].describe())
display(mostra_validacio.describe(exclude=[np.number]))
# Out:
#             Year         Month    DayofMonth     DayOfWeek     FlightNum
# count  1419011.0  1.419011e+06  1.419011e+06  1.419011e+06  1.419011e+06
# mean      2008.0  6.104650e+00  1.573738e+01  3.980556e+00  2.162547e+03
# std          0.0  3.474517e+00  8.763671e+00  1.992190e+00  1.925618e+03
# min       2008.0  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  8.000000e+00  2.000000e+00  6.060000e+02
# 50%       2008.0  6.000000e+00  1.600000e+01  4.000000e+00  1.536000e+03
# 75%       2008.0  9.000000e+00  2.300000e+01  6.000000e+00  3.384000e+03
# max       2008.0  1.200000e+01  3.100000e+01  7.000000e+00  9.741000e+03
#        UniqueCarrier  Origin    Dest
# count         354753  354753  354753
# unique            20     300     301
# top               WN     ATL     ATL
# freq           71842   24479   19154

# %% [markdown]
# #### La descripció retorna valors a nivell de máxims molt similars.

# %% [markdown]
# <html>
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=windows-1252">
# <meta name=Generator content="Microsoft Word 15 (filtered)">
# <style>
# <!--
#  /* Font Definitions */
#  @font-face
# 	{font-family:Wingdings;
# 	panose-1:5 0 0 0 0 0 0 0 0 0;}
# @font-face
# 	{font-family:"Cambria Math";
# 	panose-1:2 4 5 3 5 4 6 3 2 4;}
# @font-face
# 	{font-family:Calibri;
# 	panose-1:2 15 5 2 2 2 4 3 2 4;}
# @font-face
# 	{font-family:"Open Sans";
# 	panose-1:2 11 6 6 3 5 4 2 2 4;}
#  /* Style Definitions */
#  p.MsoNormal, li.MsoNormal, div.MsoNormal
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:0in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraph, li.MsoListParagraph, div.MsoListParagraph
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpFirst, li.MsoListParagraphCxSpFirst, div.MsoListParagraphCxSpFirst
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:0in;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpMiddle, li.MsoListParagraphCxSpMiddle, div.MsoListParagraphCxSpMiddle
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:0in;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpLast, li.MsoListParagraphCxSpLast, div.MsoListParagraphCxSpLast
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# .MsoChpDefault
# 	{font-family:"Calibri",sans-serif;}
# .MsoPapDefault
# 	{margin-bottom:8.0pt;
# 	line-height:107%;}
# @page WordSection1
# 	{size:595.3pt 841.9pt;
# 	margin:70.85pt 23.8pt 70.85pt 27.0pt;}
# div.WordSection1
# 	{page:WordSection1;}
#  /* List Definitions */
#  ol
# 	{margin-bottom:0in;}
# ul
# 	{margin-bottom:0in;}
# -->
# </style>
#
# </head>
#
# <body lang=EN-GB link="#0563C1" vlink="#954F72" style='word-wrap:break-word'>
#
# <div class=WordSection1>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><b><i><span
# lang=CA style='font-size:14.0pt;font-family:"Open Sans",sans-serif'>Nivell 2</span></i></b></p>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><span lang=CA
# style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraph style='margin-top:0in;margin-right:0in;margin-bottom:
# 0in;margin-left:.25in;text-indent:-.25in;line-height:normal'><span lang=CA
# style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>·<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><u><span lang=CA style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>Exercici
# 2</span></u></p>
#
# <p class=MsoNormal style='margin-bottom:0in;text-align:justify;line-height:
# normal'><span lang=CA style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>Aplica
# algun procés de transformació (estandarditzar les dades numèriques, crear
# columnes dummies, polinomis...).</span></p>
#
# </div>
#
# </body>
#
# </html>

# %%
# Fem l'estandardització de 2 variables de tipus numéric
columnes_a_estandaritzar = ['DepTime', 'ArrTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Distance', 'AcumulatedDelay']
vols_col_estandaritzar = preprocessing.StandardScaler().fit(mostra_entrenament[columnes_a_estandaritzar])
vols_col_estandaritzades = vols_col_estandaritzar.transform(mostra_entrenament[columnes_a_estandaritzar])

display(vols_col_estandaritzades)
# Out:
# array([[ 0.66761741,  0.80463886,  0.42224219, ..., -0.24577377,
#          0.26878248, -0.40809856],
#        [ 1.20459814,  0.79887507, -1.10901377, ..., -0.58035796,
#         -1.10069238, -0.98181007],
#        [ 0.52427086,  0.96218238,  0.50974253, ..., -0.54318193,
#          0.568464  ,         nan],
#        ...,
#        [ 0.04644902,  0.05150397,  0.21807473, ..., -0.72906204,
#          0.00743231,         nan],
#        [-0.87733986, -0.73044985,  0.13057439, ...,  0.34904256,
#         -0.08142674, -0.43359685],
#        [-0.60657415, -0.1598349 , -0.14651002, ..., -0.32012581,
#          0.16772708,         nan]])

# %%
# Afegir les columnes transformades
k = 0
columnes_a_estandaritzar_i_estandaritzades = []
for columna in columnes_a_estandaritzar:
    mostra_entrenament[columna + '_escalat'] = vols_col_estandaritzades[:,k]
    columnes_a_estandaritzar_i_estandaritzades = columnes_a_estandaritzar_i_estandaritzades + [columnes_a_estandaritzar[k]]
    columnes_a_estandaritzar_i_estandaritzades = columnes_a_estandaritzar_i_estandaritzades + [columnes_a_estandaritzar[k] + '_escalat']
    k = k + 1

print (columnes_a_estandaritzar_i_estandaritzades)
# Out:
# ['DepTime', 'DepTime_escalat', 'ArrTime', 'ArrTime_escalat', 'AirTime', 'AirTime_escalat', 'ArrDelay', 'ArrDelay_escalat', 'DepDelay', 'DepDelay_escalat', 'Distance', 'Distance_escalat', 'AcumulatedDelay', 'AcumulatedDelay_escalat']
# <ipython-input-10-d206bed307fc>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mostra_entrenament[columna + '_escalat'] = vols_col_estandaritzades[:,k]

# %%
# Visualització de la taula amb columnes estandaritzades i no estandaritzades per tal de veure i comparar
display(mostra_entrenament[columnes_a_estandaritzar_i_estandaritzades].head())
display(mostra_entrenament.head())
# Out:
#          DepTime  DepTime_escalat  ArrTime  ArrTime_escalat  AirTime  \
# id
# 536445    1800.0         0.667617   2039.0         0.804639    137.0
# 1578251   2036.0         1.204598   2036.0         0.798875     32.0
# 424434    1737.0         0.524271   2121.0         0.962182    143.0
# 1443565   1746.0         0.544749   1803.0         0.351221     63.0
# 432924    2105.0         1.361597   2210.0         1.133175     38.0
#
#          AirTime_escalat  ArrDelay  ArrDelay_escalat  DepDelay  \
# id
# 536445          0.422242      39.0          0.316842      25.0
# 1578251        -1.109014      21.0         -0.288500      16.0
# 424434          0.509743       2.0         -0.927473      17.0
# 1443565        -0.656929      28.0         -0.053089      46.0
# 432924         -1.021513      65.0          1.191226      66.0
#
#          DepDelay_escalat  Distance  Distance_escalat  AcumulatedDelay  \
# id
# 536445          -0.245774       920          0.268782         1.716667
# ...

# %%
# Creem una variable relacionada amb el retard acumulat per tal de categortizar la gravetat del retard

mostra_entrenament.loc[mostra_entrenament['ArrDelay'] <= 15, 'Gravetat_retard'] = 'Lleu'
mostra_entrenament.loc[(mostra_entrenament['ArrDelay'] > 15) & (mostra_entrenament['ArrDelay'] <= 60), 'Gravetat_retard'] = 'Greu'
mostra_entrenament.loc[mostra_entrenament['ArrDelay'] > 60, 'Gravetat_retard'] = 'Molt greu'

display(mostra_entrenament.head())
# Out:
# C:\Users\Antoni\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Antoni\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
# C:\Users\Antoni\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Fer el dummy de la columna 'Gravetat_retard'
gravetat_retard_dummy = pd.get_dummies(mostra_entrenament['Gravetat_retard'], prefix = 'Gravetat_retard')

gravetat_retard_dummy.head()
# Out:
#          Gravetat_retard_Greu  Gravetat_retard_Lleu  Gravetat_retard_Molt greu
# id
# 536445                      1                     0                          0
# 1578251                     1                     0                          0
# 424434                      0                     1                          0
# 1443565                     1                     0                          0
# 432924                      0                     0                          1

# %%
# Afegir els dummies a la taula de mostra d'entrenament
mostra_entrenament = mostra_entrenament.merge(gravetat_retard_dummy, left_index=True, right_index=True)

mostra_entrenament.head()
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# id
# 536445   2008      3          30          7   1800.0        1735   2039.0
# 1578251  2008     10          23          4   2036.0        2020   2036.0
# 424434   2008      3          13          4   1737.0        1720   2121.0
# 1443565  2008      9          26          5   1746.0        1700   1803.0
# 432924   2008      3          19          3   2105.0        1959   2210.0
#
#          CRSArrTime UniqueCarrier  FlightNum  AirTime  ArrDelay  DepDelay  \
# id
# 536445         2000            AA       1136    137.0      39.0      25.0
# 1578251        2015            DL       1597     32.0      21.0      16.0
# 424434         2119            XE       2058    143.0       2.0      17.0
# 1443565        1735            WN        268     63.0      28.0      46.0
# 432924         2105            OH       5566     38.0      65.0      66.0
#
# ...

# %%
# Eliminació de valors nuls per tal de que sigui factible crear polinomis de regressió
tamany_mostra_abans_eliminar_nulls = mostra_entrenament.shape[0]
mostra_entrenament = mostra_entrenament.dropna()
tamany_mostra_abans_després_nulls = mostra_entrenament.shape[0]

print("S'han eliminat el {}% dels casos en la mostra d'entrenament".format(round((tamany_mostra_abans_després_nulls/tamany_mostra_abans_eliminar_nulls)*100,2)))

mostra_entrenament.head()
# Out:
# S'han eliminat el 61.59% dels casos en la mostra d'entrenament
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# id
# 536445   2008      3          30          7   1800.0        1735   2039.0
# 1578251  2008     10          23          4   2036.0        2020   2036.0
# 1443565  2008      9          26          5   1746.0        1700   1803.0
# 432924   2008      3          19          3   2105.0        1959   2210.0
# 80965    2008      1          26          6   1424.0        1347   1558.0
#
#          CRSArrTime UniqueCarrier  FlightNum  AirTime  ArrDelay  DepDelay  \
# id
# 536445         2000            AA       1136    137.0      39.0      25.0
# 1578251        2015            DL       1597     32.0      21.0      16.0
# 1443565        1735            WN        268     63.0      28.0      46.0
# 432924         2105            OH       5566     38.0      65.0      66.0
# 80965          1532            UA       1570     76.0      26.0      37.0
#
# ...

# %%
# Creem un polinomi per tal d'analitzar més endavant la relació entre el retard d'arribada i la distancia recorreguda
polinomi = PolynomialFeatures(2)
polinomi_retard_distancia = polinomi.fit_transform(mostra_entrenament[['Distance_escalat','AirTime_escalat']])
polinomi_retard_distancia
# Out:
# array([[ 1.00000000e+00,  2.68782477e-01,  4.22242190e-01,
#          7.22440200e-02,  1.13491302e-01,  1.78288467e-01],
#        [ 1.00000000e+00, -1.10069238e+00, -1.10901377e+00,
#          1.21152371e+00,  1.22068301e+00,  1.22991155e+00],
#        [ 1.00000000e+00, -5.62311042e-01, -6.56928678e-01,
#          3.16193708e-01,  3.69398250e-01,  4.31555289e-01],
#        ...,
#        [ 1.00000000e+00,  6.15507027e-01,  4.95159140e-01,
#          3.78848900e-01,  3.04773930e-01,  2.45182574e-01],
#        [ 1.00000000e+00,  3.13492260e+00,  3.52850428e+00,
#          9.82773972e+00,  1.10615878e+01,  1.24503425e+01],
#        [ 1.00000000e+00, -8.14267418e-02,  1.30574388e-01,
#          6.63031428e-03, -1.06322469e-02,  1.70496707e-02]])

# %% [markdown]
# <html>
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=windows-1252">
# <meta name=Generator content="Microsoft Word 15 (filtered)">
# <style>
# <!--
#  /* Font Definitions */
#  @font-face
# 	{font-family:Wingdings;
# 	panose-1:5 0 0 0 0 0 0 0 0 0;}
# @font-face
# 	{font-family:"Cambria Math";
# 	panose-1:2 4 5 3 5 4 6 3 2 4;}
# @font-face
# 	{font-family:Calibri;
# 	panose-1:2 15 5 2 2 2 4 3 2 4;}
# @font-face
# 	{font-family:"Open Sans";
# 	panose-1:2 11 6 6 3 5 4 2 2 4;}
#  /* Style Definitions */
#  p.MsoNormal, li.MsoNormal, div.MsoNormal
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:0in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraph, li.MsoListParagraph, div.MsoListParagraph
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpFirst, li.MsoListParagraphCxSpFirst, div.MsoListParagraphCxSpFirst
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:0in;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpMiddle, li.MsoListParagraphCxSpMiddle, div.MsoListParagraphCxSpMiddle
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:0in;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# p.MsoListParagraphCxSpLast, li.MsoListParagraphCxSpLast, div.MsoListParagraphCxSpLast
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:8.0pt;
# 	margin-left:.5in;
# 	line-height:107%;
# 	font-size:11.0pt;
# 	font-family:"Calibri",sans-serif;}
# .MsoChpDefault
# 	{font-family:"Calibri",sans-serif;}
# .MsoPapDefault
# 	{margin-bottom:8.0pt;
# 	line-height:107%;}
# @page WordSection1
# 	{size:595.3pt 841.9pt;
# 	margin:70.85pt 23.8pt 70.85pt 27.0pt;}
# div.WordSection1
# 	{page:WordSection1;}
#  /* List Definitions */
#  ol
# 	{margin-bottom:0in;}
# ul
# 	{margin-bottom:0in;}
# -->
# </style>
#
# </head>
#
# <body lang=EN-GB link="#0563C1" vlink="#954F72" style='word-wrap:break-word'>
#
# <div class=WordSection1>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><b><i><span
# lang=CA style='font-size:14.0pt;font-family:"Open Sans",sans-serif'>Nivell 3</span></i></b></p>
#
# <p class=MsoNormal style='margin-bottom:0in;line-height:normal'><span lang=CA
# style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>&nbsp;</span></p>
#
# <p class=MsoListParagraph style='margin-top:0in;margin-right:0in;margin-bottom:
# 0in;margin-left:.25in;text-indent:-.25in;line-height:normal'><span lang=CA
# style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>·<span
# style='font:7.0pt "Times New Roman"'>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# </span></span><u><span lang=CA style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>Exercici
# 3</span></u></p>
#
# <p class=MsoNormal style='margin-bottom:0in;text-align:justify;line-height:
# normal'><span lang=CA style='font-size:12.0pt;font-family:"Open Sans",sans-serif'>Resumeix
# les noves columnes generades de manera estadística i gràfica.</span></p>
#
# </div>
#
# </body>
#
# </html>

# %%
# Estadístics de les noves columnes generades estandaritzades
mostra_entrenament[columnes_a_estandaritzar_i_estandaritzades].describe().round(2)
# Out:
#          DepTime  DepTime_escalat    ArrTime  ArrTime_escalat    AirTime  \
# count  874016.00        874016.00  874016.00        874016.00  874016.00
# mean     1544.99             0.09    1634.18             0.03     106.92
# std       438.67             1.00     546.25             1.05      68.02
# min         1.00            -3.43       1.00            -3.11       0.00
# 25%      1222.00            -0.65    1334.00            -0.55      58.00
# 50%      1604.00             0.22    1733.00             0.22      89.00
# 75%      1912.00             0.92    2043.00             0.81     136.00
# max      2400.00             2.03    2400.00             1.50     664.00
#
#        AirTime_escalat   ArrDelay  ArrDelay_escalat   DepDelay  \
# count        874016.00  874016.00         874016.00  874016.00
# mean             -0.02      45.81              0.55      43.40
# std               0.99      26.68              0.90      28.06
# ...

# %% [markdown]
# Les variables estandarditzades tenen aproximademanet mitja 0 i aproximadament desviació típica 1

# %%
# Visualització dels histogrames per a les columnes estandaritzades i no estandaritzades
mostra_entrenament[['DepTime', 'DepTime_escalat']].hist(bins=25, color="Green")
# Out:
# array([[<AxesSubplot:title={'center':'DepTime'}>,
#         <AxesSubplot:title={'center':'DepTime_escalat'}>]], dtype=object)

# %%
mostra_entrenament[['ArrTime', 'ArrTime_escalat']].hist(bins=25, color="Green")
# Out:
# array([[<AxesSubplot:title={'center':'ArrTime'}>,
#         <AxesSubplot:title={'center':'ArrTime_escalat'}>]], dtype=object)

# %%
mostra_entrenament[['AirTime', 'AirTime_escalat']].hist(bins=25, color="Green")
# Out:
# array([[<AxesSubplot:title={'center':'AirTime'}>,
#         <AxesSubplot:title={'center':'AirTime_escalat'}>]], dtype=object)

# %%
mostra_entrenament[['ArrDelay', 'ArrDelay_escalat']].hist(bins=25, color="Green")
# Out:
# array([[<AxesSubplot:title={'center':'ArrDelay'}>,
#         <AxesSubplot:title={'center':'ArrDelay_escalat'}>]], dtype=object)

# %%
mostra_entrenament[['DepDelay', 'DepDelay_escalat']].hist(bins=25, color="Green")
# Out:
# array([[<AxesSubplot:title={'center':'DepDelay'}>,
#         <AxesSubplot:title={'center':'DepDelay_escalat'}>]], dtype=object)

# %%
mostra_entrenament[['Distance', 'Distance_escalat']].hist(bins=25, color="Green")
# Out:
# array([[<AxesSubplot:title={'center':'Distance'}>,
#         <AxesSubplot:title={'center':'Distance_escalat'}>]], dtype=object)

# %%
mostra_entrenament[['AcumulatedDelay', 'AcumulatedDelay_escalat']].hist(bins=25, color="Green")
# Out:
# array([[<AxesSubplot:title={'center':'AcumulatedDelay'}>,
#         <AxesSubplot:title={'center':'AcumulatedDelay_escalat'}>]],
#       dtype=object)

# %% [markdown]
# Pel que sembla, no n'hi ha cap que segueixi una distribució normal.

# %%
# Visualització de la relació entre distancia recorreguda i temps de vol estandaritzats
sns.scatterplot(x='Distance_escalat',y='AirTime_escalat',data=mostra_entrenament, s=4, color='red')
# Out:
# <AxesSubplot:xlabel='Distance_escalat', ylabel='AirTime_escalat'>

# %% [markdown]
# Sembla que hi ha una correlació lineal positiva entre aquestes 2 variables.

# %%
# # Visualització de la freqúencia dels diferents tipus de gravetats per retard: lleu, greu i molt greu.
mostra_entrenament_gravetat_retard = mostra_entrenament['Gravetat_retard'].value_counts()
plt.figure(figsize = (14,12))
plt.pie(mostra_entrenament_gravetat_retard, labels = mostra_entrenament_gravetat_retard.index, autopct='%1.1f%%',shadow = True, textprops={'fontsize': 14})
plt.title('Percentatge de vols sobre el total i per companyia',fontsize = 28)
plt.show()

# %% [markdown]
# LAmajor part dels retads son greus, 71% i molt greus, 26%.
