# %% [markdown]
# ## Nivell 1
#
#
# - Exercici 1
#
# Crea una base relacional d’exemple utilitzant un document de text o a mà. Dissenya-la perquè contingui les següents taules, i estableix les relacions que consideris necessàries entre elles:
#
# -	Taula de compres (transaccions)
#
# -	Taula d’establiments
#
# -	Taula de treballadors
#
# -	Taula de clients
#
# -	Taula de productes
#
# -	Taula de tipus de productes
#
# Defineix les propietats de les relacions (1:1, 1:n, n:n), i crea algunes de les variables que podrien contenir, per exemple:
#
#
# Taula d’establiments
#
# -	IDestabliment (unique key)
#
# -	Nom
#
# -	Localització
#
# -	Superfície

# %%
from IPython import display

# Croquis done with Excel
image_file = "H:\_vertex\_formacio\_python - cibernarium\_17\_17_04\_diagrama_croquis.jpg"
display.Image(image_file,height= 1024, width = 1024)

# %% [markdown]
# ## Nivell 2
#
# - Exercici 2
#
#     Utilitza un programa de creació de diagrames entitat-relació com http://dia-installer.de per crear el diagrama.

# %%
# Diagram done with the software recomended in the exercise 
image_file = "H:\_vertex\_formacio\_python - cibernarium\_17\_17_04\_diagrama_croquis_dia.jpeg"
display.Image(image_file,height= 1024, width = 1024)

# %% [markdown]
# ## Nivell 3
#
# - Exercici 3
#
#     Utilitza el Workbench de MySQL per crear un model relacional.

# %%
# Diagram done with the PostgreSQL Entity Relationship Diagram tool.
# Not done with MySQL because I have experimented som problemes during instalation
image_file = "H:\_vertex\_formacio\_python - cibernarium\_17\_17_04\_diagrama_croquis_dia_postgresql.pgerd.jpeg"
display.Image(image_file,height= 1024, width = 1024)
